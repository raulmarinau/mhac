# %%
import sys
sys.path.append("/home/marin/projects/mhac/build/release")
import mhac

# %%
# %matplotlib inline
import os, random, copy, math, csv
import matplotlib.pyplot as plt
import numpy as np

# %%
mhac.set_log_level(mhac.LogLevel.off)

# %%
def read_file_input(filepath):
    with open(filepath) as f:
        lines = f.readlines()
        sizes = [int(nr) for nr in lines[0].split()]
        m, n = sizes[0], sizes[1]
        arr = np.zeros((n, m))

        for i in range(1, len(lines)):
            arr[i-1, :] = [int(nr) for nr in lines[i].split()]

    return arr

# %%
def nparray_to_timematrix(arr):
    tm = mhac.problems.jss.TimeMatrix()

    for time_list in arr.tolist():
        vint = mhac.VectorInt()
        for time in time_list:
            vint.append(int(time))
        tm.append(vint)

    return tm

# %%
problem = mhac.problems.jss.JSSP(nparray_to_timematrix(read_file_input("../../data/jss/imrg/ds1/testbed_1_s/t1s_0001.txt")))
TS = mhac.math.TabuSearch(problem)
sol = TS.solve(1000, 10, 20)
sol.schedule
# Out:
# VectorInt[0, 1, 3, 2, 4]

# %%
sol.cost
# Out:
# 819.0

# %%
folder_path = "../../data/jss/imrg/ds1/testbed_1_s"
output_file = "results.csv"

# %%
def read_all_files_in_folder(folder_path):
    # List to hold file contents
    file_contents = {}

    # Check if the provided path is a directory
    if not os.path.isdir(folder_path):
        raise ValueError(f"The provided path '{folder_path}' is not a valid directory.")

    # Iterate over all files in the directory
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)

        # Check if it's a file
        if os.path.isfile(file_path):
            try:
                # Open and read the file
                with open(file_path, 'r') as file:
                    content = file.read()
                    file_contents[filename] = content
            except Exception as e:
                print(f"Error reading file {filename}: {e}")
    
    return file_contents

# %%
def process_files(file_data):
    # Example function to process file data
    results = []
    for filename, content in file_data.items():
        print(f"Processing file: {filename}")
        problem = mhac.problems.jss.JSSP(nparray_to_timematrix(read_file_input(f"{folder_path}/{filename}")))
        TS = mhac.math.TabuSearch(problem)
        sol = TS.solve(1000, 10, 20)
        results.append({"filename": filename, "cost": sol.cost })
        print(sol.schedule)
        print(sol.cost)
    return results

# %%
def write_results_to_csv(results, output_file):
    with open(output_file, 'w', newline='') as csvfile:
        fieldnames = ['filename', 'cost']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        
        writer.writeheader()
        for result in results:
            writer.writerow(result)

# %%
file_data = read_all_files_in_folder(folder_path)

# %%
results = process_files(file_data)
# Out:
# Processing file: t1s_0238.txt
# VectorInt[5, 2, 3, 8, 9, 1, 4, 7, 0, 6]
# 10843.0
# Processing file: t1s_0216.txt
# VectorInt[1, 4, 6, 7, 5, 8, 9, 2, 3, 0]
# 12034.0
# Processing file: t1s_0312.txt
# VectorInt[5, 10, 11, 8, 1, 6, 4, 9, 3, 2, 7, 0]
# 10079.0
# Processing file: t1s_0281.txt
# VectorInt[1, 10, 8, 6, 7, 2, 4, 5, 0, 9, 3, 11]
# 6182.0
# Processing file: t1s_0113.txt
# VectorInt[2, 0, 3, 4, 1]
# 4745.0
# Processing file: t1s_0082.txt
# VectorInt[3, 0, 1, 4, 2]
# 2624.0
# Processing file: t1s_0192.txt
# VectorInt[4, 3, 1, 7, 8, 5, 2, 9, 6, 0]
# 7746.0
# Processing file: t1s_0266.txt
# VectorInt[1, 5, 2, 0, 10, 11, 7, 9, 6, 8, 3, 4]
# 4071.0
# Processing file: t1s_0021.txt
# VectorInt[0, 1, 4, 2, 3]
# 886.0
# Processing file: t1s_0018.txt
# VectorInt[2, 0, 1, 3, 4]
# 832.0
# Processing file: t1s_0162.txt
# VectorInt[1, 6, 4, 0, 2, 9, 8, 3, 5, 7]
# 5157.0
# Processing file: t1s_0147.txt
# VectorInt[4, 1, 5, 9, 8, 6, 0, 2, 3, 7]
# 3232.0
# Processing file: t1s_0183.txt
# VectorInt[7, 2, 5, 6, 1, 4, 9, 8, 3, 0]
# 6897.0
# Processing file: t1s_0346.txt
# VectorInt[4, 3, 7, 6, 8, 0, 9, 2, 5, 10, 1, 11]
# 15300.0
# Processing file: t1s_0062.txt
# VectorInt[4, 2, 0, 1, 3]
# 2423.0
# Processing file: t1s_0027.txt
# VectorInt[0, 2, 4, 1, 3]
# 944.0
# Processing file: t1s_0200.txt
# VectorInt[7, 6, 3, 4, 8, 0, 2, 9, 1, 5]
# 7209.0
# Processing file: t1s_0111.txt
# VectorInt[0, 4, 2, 1, 3]
# 4657.0
# Processing file: t1s_0213.txt
# VectorInt[3, 0, 7, 2, 5, 8, 4, 1, 6, 9]
# 12641.0
# Processing file: t1s_0034.txt
# VectorInt[0, 4, 2, 3, 1]
# 1445.0
# Processing file: t1s_0295.txt
# VectorInt[6, 8, 0, 9, 10, 5, 11, 3, 2, 7, 4, 1]
# 5615.0
# Processing file: t1s_0057.txt
# VectorInt[2, 4, 1, 3, 0]
# 1842.0
# Processing file: t1s_0328.txt
# VectorInt[2, 6, 11, 4, 8, 10, 5, 3, 1, 0, 7, 9]
# 9157.0
# Processing file: t1s_0218.txt
# VectorInt[5, 4, 8, 6, 1, 9, 7, 2, 3, 0]
# 12350.0
# Processing file: t1s_0234.txt
# VectorInt[8, 4, 2, 5, 7, 9, 1, 3, 0, 6]
# 12757.0
# Processing file: t1s_0223.txt
# VectorInt[7, 2, 8, 3, 9, 0, 6, 4, 1, 5]
# 11912.0
# Processing file: t1s_0137.txt
# VectorInt[7, 1, 2, 0, 4, 8, 5, 6, 3, 9]
# 2889.0
# Processing file: t1s_0253.txt
# VectorInt[4, 8, 7, 10, 5, 3, 0, 6, 1, 11, 9, 2]
# 2916.0
# Processing file: t1s_0118.txt
# VectorInt[1, 0, 4, 2, 3]
# 4188.0
# Processing file: t1s_0306.txt
# VectorInt[3, 0, 2, 1, 6, 4, 7, 9, 8, 10, 5, 11]
# 9751.0
# Processing file: t1s_0148.txt
# VectorInt[7, 2, 3, 5, 8, 9, 1, 0, 4, 6]
# 2466.0
# Processing file: t1s_0303.txt
# VectorInt[11, 5, 3, 4, 8, 10, 1, 0, 6, 7, 2, 9]
# 10599.0
# Processing file: t1s_0231.txt
# VectorInt[7, 1, 5, 6, 9, 2, 8, 0, 3, 4]
# 12478.0
# Processing file: t1s_0117.txt
# VectorInt[1, 0, 2, 3, 4]
# 4745.0
# Processing file: t1s_0240.txt
# VectorInt[6, 7, 0, 1, 5, 3, 8, 4, 2, 9]
# 11866.0
# Processing file: t1s_0114.txt
# VectorInt[0, 3, 1, 4, 2]
# 4949.0
# Processing file: t1s_0107.txt
# VectorInt[4, 0, 1, 3, 2]
# 4802.0
# Processing file: t1s_0316.txt
# VectorInt[7, 0, 3, 10, 6, 11, 4, 8, 5, 1, 2, 9]
# 9532.0
# Processing file: t1s_0206.txt
# VectorInt[9, 3, 4, 6, 2, 8, 5, 0, 7, 1]
# 7038.0
# Processing file: t1s_0070.txt
# VectorInt[3, 1, 0, 4, 2]
# 2674.0
# Processing file: t1s_0229.txt
# VectorInt[4, 0, 8, 5, 2, 7, 3, 9, 1, 6]
# 12387.0
# Processing file: t1s_0071.txt
# VectorInt[3, 4, 2, 0, 1]
# 2458.0
# Processing file: t1s_0252.txt
# VectorInt[9, 2, 4, 5, 3, 1, 11, 0, 10, 8, 6, 7]
# 4783.0
# Processing file: t1s_0108.txt
# VectorInt[4, 3, 0, 2, 1]
# 5012.0
# Processing file: t1s_0168.txt
# VectorInt[4, 1, 8, 9, 5, 2, 0, 7, 6, 3]
# 4266.0
# Processing file: t1s_0349.txt
# VectorInt[8, 1, 2, 0, 6, 4, 5, 9, 7, 3, 11, 10]
# 16242.0
# Processing file: t1s_0131.txt
# VectorInt[3, 8, 5, 4, 2, 0, 6, 1, 9, 7]
# 2610.0
# Processing file: t1s_0158.txt
# VectorInt[9, 4, 8, 6, 2, 0, 5, 7, 1, 3]
# 4739.0
# Processing file: t1s_0326.txt
# VectorInt[2, 1, 10, 0, 9, 3, 5, 8, 7, 11, 6, 4]
# 8825.0
# Processing file: t1s_0248.txt
# VectorInt[4, 1, 10, 3, 2, 7, 0, 11, 6, 9, 5, 8]
# 2944.0
# Processing file: t1s_0146.txt
# VectorInt[5, 2, 1, 0, 6, 7, 9, 3, 8, 4]
# 2466.0
# Processing file: t1s_0129.txt
# VectorInt[9, 7, 4, 1, 8, 6, 5, 0, 2, 3]
# 2545.0
# Processing file: t1s_0275.txt
# VectorInt[5, 11, 3, 7, 4, 1, 6, 8, 9, 10, 2, 0]
# 6163.0
# Processing file: t1s_0130.txt
# VectorInt[0, 4, 9, 2, 8, 5, 3, 1, 7, 6]
# 2362.0
# Processing file: t1s_0221.txt
# VectorInt[2, 1, 0, 4, 7, 5, 9, 6, 8, 3]
# 11357.0
# Processing file: t1s_0350.txt
# VectorInt[0, 11, 9, 5, 2, 4, 8, 10, 1, 6, 3, 7]
# 15077.0
# Processing file: t1s_0322.txt
# VectorInt[4, 7, 0, 8, 1, 3, 9, 10, 2, 5, 11, 6]
# 8861.0
# Processing file: t1s_0246.txt
# VectorInt[5, 7, 1, 4, 0, 2, 8, 9, 6, 11, 10, 3]
# 4143.0
# Processing file: t1s_0232.txt
# VectorInt[6, 3, 8, 5, 7, 4, 2, 0, 9, 1]
# 12395.0
# Processing file: t1s_0068.txt
# VectorInt[2, 0, 3, 1, 4]
# 2656.0
# Processing file: t1s_0208.txt
# VectorInt[6, 4, 5, 2, 1, 9, 0, 3, 7, 8]
# 6654.0
# Processing file: t1s_0049.txt
# VectorInt[4, 0, 2, 3, 1]
# 1509.0
# Processing file: t1s_0144.txt
# VectorInt[7, 8, 2, 5, 9, 1, 6, 3, 0, 4]
# 1984.0
# Processing file: t1s_0014.txt
# VectorInt[4, 2, 3, 1, 0]
# 904.0
# Processing file: t1s_0277.txt
# VectorInt[3, 4, 7, 11, 1, 6, 5, 8, 9, 0, 10, 2]
# 6076.0
# Processing file: t1s_0091.txt
# VectorInt[0, 1, 4, 3, 2]
# 4374.0
# Processing file: t1s_0324.txt
# VectorInt[6, 10, 11, 7, 2, 1, 0, 5, 8, 3, 4, 9]
# 9061.0
# Processing file: t1s_0239.txt
# VectorInt[5, 3, 8, 9, 6, 0, 2, 1, 4, 7]
# 11597.0
# Processing file: t1s_0255.txt
# VectorInt[4, 0, 1, 5, 3, 2, 9, 7, 10, 6, 11, 8]
# 4015.0
# Processing file: t1s_0157.txt
# VectorInt[6, 2, 8, 0, 7, 1, 9, 3, 4, 5]
# 4936.0
# Processing file: t1s_0115.txt
# VectorInt[1, 0, 4, 3, 2]
# 4657.0
# Processing file: t1s_0048.txt
# VectorInt[4, 2, 3, 0, 1]
# 1402.0
# Processing file: t1s_0040.txt
# VectorInt[2, 3, 1, 4, 0]
# 1984.0
# Processing file: t1s_0119.txt
# VectorInt[4, 3, 0, 1, 2]
# 4683.0
# Processing file: t1s_0133.txt
# VectorInt[2, 5, 3, 0, 8, 6, 4, 1, 9, 7]
# 3869.0
# Processing file: t1s_0210.txt
# VectorInt[1, 3, 0, 2, 9, 4, 6, 8, 7, 5]
# 6864.0
# Processing file: t1s_0178.txt
# VectorInt[0, 4, 9, 2, 8, 7, 5, 1, 3, 6]
# 5073.0
# Processing file: t1s_0333.txt
# VectorInt[2, 1, 4, 6, 0, 5, 11, 10, 9, 3, 7, 8]
# 15826.0
# Processing file: t1s_0261.txt
# VectorInt[2, 7, 5, 9, 1, 3, 8, 0, 11, 10, 6, 4]
# 3682.0
# Processing file: t1s_0029.txt
# VectorInt[1, 2, 0, 3, 4]
# 655.0
# Processing file: t1s_0059.txt
# VectorInt[3, 4, 1, 2, 0]
# 1788.0
# Processing file: t1s_0024.txt
# VectorInt[0, 4, 3, 1, 2]
# 1035.0
# Processing file: t1s_0035.txt
# VectorInt[0, 3, 1, 4, 2]
# 1745.0
# Processing file: t1s_0280.txt
# VectorInt[0, 11, 4, 3, 2, 10, 9, 6, 7, 5, 1, 8]
# 5640.0
# Processing file: t1s_0313.txt
# VectorInt[0, 6, 5, 11, 3, 7, 4, 1, 8, 10, 9, 2]
# 10038.0
# Processing file: t1s_0314.txt
# VectorInt[5, 2, 8, 10, 3, 9, 1, 11, 6, 4, 7, 0]
# 10256.0
# Processing file: t1s_0309.txt
# VectorInt[10, 11, 2, 6, 5, 3, 9, 8, 4, 1, 7, 0]
# 9676.0
# Processing file: t1s_0274.txt
# VectorInt[1, 8, 11, 4, 5, 3, 7, 2, 0, 9, 10, 6]
# 6260.0
# Processing file: t1s_0265.txt
# VectorInt[3, 2, 7, 5, 0, 9, 10, 8, 6, 11, 1, 4]
# 3113.0
# Processing file: t1s_0169.txt
# VectorInt[3, 9, 2, 4, 6, 0, 5, 7, 8, 1]
# 4186.0
# Processing file: t1s_0230.txt
# VectorInt[7, 0, 1, 4, 3, 5, 6, 8, 2, 9]
# 13084.0
# Processing file: t1s_0051.txt
# VectorInt[3, 2, 0, 1, 4]
# 1659.0
# Processing file: t1s_0305.txt
# VectorInt[11, 4, 0, 2, 9, 6, 8, 3, 5, 7, 10, 1]
# 9756.0
# Processing file: t1s_0022.txt
# VectorInt[3, 1, 4, 2, 0]
# 871.0
# Processing file: t1s_0187.txt
# VectorInt[7, 5, 1, 8, 0, 2, 3, 9, 6, 4]
# 7804.0
# Processing file: t1s_0151.txt
# VectorInt[7, 4, 1, 5, 2, 6, 0, 3, 9, 8]
# 4508.0
# Processing file: t1s_0287.txt
# VectorInt[5, 10, 6, 9, 8, 3, 11, 2, 4, 0, 1, 7]
# 6510.0
# Processing file: t1s_0081.txt
# VectorInt[4, 0, 3, 2, 1]
# 2721.0
# Processing file: t1s_0072.txt
# VectorInt[0, 3, 2, 1, 4]
# 2541.0
# Processing file: t1s_0124.txt
# VectorInt[9, 1, 6, 4, 8, 5, 7, 3, 2, 0]
# 2520.0
# Processing file: t1s_0065.txt
# VectorInt[2, 3, 0, 1, 4]
# 2586.0
# Processing file: t1s_0180.txt
# VectorInt[3, 4, 9, 1, 0, 8, 5, 6, 2, 7]
# 4199.0
# Processing file: t1s_0212.txt
# VectorInt[4, 3, 0, 8, 2, 1, 7, 9, 6, 5]
# 12601.0
# Processing file: t1s_0028.txt
# VectorInt[2, 1, 4, 0, 3]
# 1027.0
# Processing file: t1s_0355.txt
# VectorInt[5, 10, 3, 8, 2, 0, 6, 1, 11, 7, 4, 9]
# 15630.0
# Processing file: t1s_0299.txt
# VectorInt[9, 8, 10, 5, 6, 3, 11, 2, 4, 1, 7, 0]
# 5469.0
# Processing file: t1s_0174.txt
# VectorInt[5, 1, 8, 4, 6, 3, 0, 7, 2, 9]
# 4470.0
# Processing file: t1s_0186.txt
# VectorInt[0, 1, 9, 6, 2, 5, 7, 3, 4, 8]
# 7171.0
# Processing file: t1s_0331.txt
# VectorInt[0, 5, 6, 9, 1, 8, 2, 4, 10, 7, 11, 3]
# 15653.0
# Processing file: t1s_0222.txt
# VectorInt[0, 9, 2, 5, 6, 7, 8, 1, 3, 4]
# 12187.0
# Processing file: t1s_0352.txt
# VectorInt[5, 6, 8, 10, 0, 1, 7, 9, 11, 3, 4, 2]
# 15473.0
# Processing file: t1s_0329.txt
# VectorInt[2, 5, 6, 3, 1, 4, 8, 9, 11, 0, 7, 10]
# 8897.0
# Processing file: t1s_0190.txt
# VectorInt[6, 3, 5, 1, 0, 7, 8, 9, 4, 2]
# 7283.0
# Processing file: t1s_0343.txt
# VectorInt[2, 8, 1, 5, 3, 7, 11, 6, 9, 0, 4, 10]
# 15676.0
# Processing file: t1s_0357.txt
# VectorInt[9, 3, 8, 6, 11, 10, 2, 7, 5, 1, 0, 4]
# 16599.0
# Processing file: t1s_0076.txt
# VectorInt[2, 0, 3, 1, 4]
# 2772.0
# Processing file: t1s_0015.txt
# VectorInt[4, 1, 3, 2, 0]
# 1010.0
# Processing file: t1s_0327.txt
# VectorInt[9, 8, 6, 5, 3, 7, 2, 4, 10, 0, 11, 1]
# 10062.0
# Processing file: t1s_0161.txt
# VectorInt[4, 1, 5, 9, 3, 2, 6, 0, 7, 8]
# 4293.0
# Processing file: t1s_0260.txt
# VectorInt[8, 4, 2, 1, 3, 9, 6, 11, 10, 0, 7, 5]
# 3363.0
# Processing file: t1s_0311.txt
# VectorInt[8, 10, 2, 6, 0, 9, 3, 7, 11, 1, 5, 4]
# 8375.0
# Processing file: t1s_0099.txt
# VectorInt[4, 2, 3, 0, 1]
# 4624.0
# Processing file: t1s_0105.txt
# VectorInt[0, 3, 2, 1, 4]
# 4395.0
# Processing file: t1s_0079.txt
# VectorInt[4, 3, 1, 0, 2]
# 2506.0
# Processing file: t1s_0256.txt
# VectorInt[7, 0, 11, 4, 2, 8, 9, 1, 5, 10, 3, 6]
# 4606.0
# Processing file: t1s_0269.txt
# VectorInt[2, 9, 1, 7, 0, 3, 4, 6, 10, 5, 11, 8]
# 3283.0
# Processing file: t1s_0077.txt
# VectorInt[1, 4, 2, 0, 3]
# 2568.0
# Processing file: t1s_0125.txt
# VectorInt[7, 0, 9, 1, 3, 2, 5, 8, 4, 6]
# 3498.0
# Processing file: t1s_0263.txt
# VectorInt[1, 11, 2, 8, 6, 0, 3, 10, 7, 5, 9, 4]
# 3882.0
# Processing file: t1s_0296.txt
# VectorInt[9, 6, 0, 3, 11, 5, 10, 7, 1, 4, 2, 8]
# 5767.0
# Processing file: t1s_0149.txt
# VectorInt[9, 0, 5, 4, 2, 1, 7, 8, 3, 6]
# 3084.0
# Processing file: t1s_0106.txt
# VectorInt[3, 1, 4, 2, 0]
# 4454.0
# Processing file: t1s_0152.txt
# VectorInt[8, 1, 2, 6, 7, 3, 4, 0, 5, 9]
# 4679.0
# Processing file: t1s_0288.txt
# VectorInt[5, 7, 8, 2, 9, 4, 6, 3, 0, 1, 11, 10]
# 5728.0
# Processing file: t1s_0345.txt
# VectorInt[11, 10, 7, 9, 3, 6, 2, 5, 0, 4, 8, 1]
# 15646.0
# Processing file: t1s_0056.txt
# VectorInt[0, 4, 3, 1, 2]
# 1543.0
# Processing file: t1s_0013.txt
# VectorInt[1, 4, 2, 3, 0]
# 1035.0
# Processing file: t1s_0282.txt
# VectorInt[6, 9, 0, 4, 11, 10, 7, 8, 2, 1, 3, 5]
# 5975.0
# Processing file: t1s_0031.txt
# VectorInt[0, 3, 2, 4, 1]
# 1431.0
# Processing file: t1s_0335.txt
# VectorInt[0, 1, 10, 7, 3, 5, 8, 11, 2, 6, 4, 9]
# 15178.0
# Processing file: t1s_0300.txt
# VectorInt[4, 11, 3, 0, 1, 7, 8, 10, 2, 5, 6, 9]
# 5138.0
# Processing file: t1s_0179.txt
# VectorInt[6, 8, 4, 0, 2, 5, 1, 7, 3, 9]
# 4658.0
# Processing file: t1s_0344.txt
# VectorInt[8, 9, 1, 3, 10, 0, 5, 6, 4, 2, 7, 11]
# 15684.0
# Processing file: t1s_0009.txt
# VectorInt[4, 1, 3, 0, 2]
# 978.0
# Processing file: t1s_0291.txt
# VectorInt[6, 2, 5, 8, 11, 9, 1, 0, 4, 10, 3, 7]
# 6365.0
# Processing file: t1s_0060.txt
# VectorInt[0, 2, 3, 1, 4]
# 1662.0
# Processing file: t1s_0042.txt
# VectorInt[0, 2, 1, 3, 4]
# 1594.0
# Processing file: t1s_0153.txt
# VectorInt[3, 5, 7, 9, 0, 1, 2, 6, 4, 8]
# 4381.0
# Processing file: t1s_0264.txt
# VectorInt[8, 0, 5, 4, 11, 3, 10, 1, 7, 9, 6, 2]
# 3866.0
# Processing file: t1s_0203.txt
# VectorInt[9, 6, 2, 7, 0, 4, 3, 8, 1, 5]
# 6910.0
# Processing file: t1s_0094.txt
# VectorInt[1, 3, 0, 4, 2]
# 4813.0
# Processing file: t1s_0211.txt
# VectorInt[7, 0, 1, 5, 3, 2, 6, 8, 4, 9]
# 12192.0
# Processing file: t1s_0196.txt
# VectorInt[6, 1, 9, 0, 4, 2, 8, 7, 5, 3]
# 7715.0
# Processing file: t1s_0164.txt
# VectorInt[0, 1, 4, 7, 3, 5, 9, 8, 2, 6]
# 4545.0
# Processing file: t1s_0342.txt
# VectorInt[10, 5, 11, 6, 3, 1, 8, 7, 4, 2, 0, 9]
# 16970.0
# Processing file: t1s_0271.txt
# VectorInt[6, 4, 1, 7, 8, 0, 2, 5, 11, 3, 9, 10]
# 5036.0
# Processing file: t1s_0025.txt
# VectorInt[2, 4, 3, 1, 0]
# 758.0
# Processing file: t1s_0141.txt
# VectorInt[2, 8, 9, 3, 7, 4, 6, 1, 5, 0]
# 2736.0
# Processing file: t1s_0336.txt
# VectorInt[0, 3, 1, 2, 8, 4, 10, 11, 9, 5, 6, 7]
# 16653.0
# Processing file: t1s_0145.txt
# VectorInt[0, 1, 9, 5, 7, 2, 6, 8, 4, 3]
# 2243.0
# Processing file: t1s_0039.txt
# VectorInt[2, 0, 3, 4, 1]
# 1611.0
# Processing file: t1s_0100.txt
# VectorInt[1, 2, 4, 3, 0]
# 4743.0
# Processing file: t1s_0284.txt
# VectorInt[3, 4, 1, 6, 9, 5, 0, 11, 7, 8, 2, 10]
# 5942.0
# Processing file: t1s_0098.txt
# VectorInt[3, 4, 2, 1, 0]
# 4271.0
# Processing file: t1s_0297.txt
# VectorInt[0, 3, 4, 11, 6, 9, 2, 5, 8, 7, 1, 10]
# 5996.0
# Processing file: t1s_0185.txt
# VectorInt[7, 2, 4, 8, 6, 0, 1, 9, 5, 3]
# 7232.0
# Processing file: t1s_0046.txt
# VectorInt[4, 2, 3, 0, 1]
# 1391.0
# Processing file: t1s_0227.txt
# VectorInt[1, 9, 3, 0, 4, 5, 2, 7, 8, 6]
# 12156.0
# Processing file: t1s_0301.txt
# VectorInt[9, 3, 6, 7, 5, 10, 1, 8, 11, 4, 2, 0]
# 8853.0
# Processing file: t1s_0165.txt
# VectorInt[3, 5, 7, 9, 0, 8, 4, 1, 6, 2]
# 3950.0
# Processing file: t1s_0268.txt
# VectorInt[5, 2, 6, 7, 4, 10, 9, 8, 3, 1, 0, 11]
# 2859.0
# Processing file: t1s_0251.txt
# VectorInt[1, 7, 11, 10, 9, 6, 0, 5, 4, 3, 8, 2]
# 4699.0
# Processing file: t1s_0088.txt
# VectorInt[0, 1, 3, 2, 4]
# 2059.0
# Processing file: t1s_0128.txt
# VectorInt[2, 7, 3, 4, 9, 5, 8, 6, 1, 0]
# 3112.0
# Processing file: t1s_0110.txt
# VectorInt[1, 3, 0, 4, 2]
# 4771.0
# Processing file: t1s_0225.txt
# VectorInt[8, 2, 1, 9, 7, 6, 0, 4, 3, 5]
# 11918.0
# Processing file: t1s_0338.txt
# VectorInt[5, 10, 4, 9, 7, 6, 2, 3, 1, 0, 8, 11]
# 16163.0
# Processing file: t1s_0063.txt
# VectorInt[2, 3, 4, 1, 0]
# 2309.0
# Processing file: t1s_0226.txt
# VectorInt[2, 1, 3, 6, 9, 4, 7, 8, 0, 5]
# 12136.0
# Processing file: t1s_0160.txt
# VectorInt[2, 4, 0, 1, 3, 8, 9, 5, 7, 6]
# 4161.0
# Processing file: t1s_0209.txt
# VectorInt[2, 7, 6, 1, 9, 5, 8, 0, 3, 4]
# 7022.0
# Processing file: t1s_0193.txt
# VectorInt[7, 5, 3, 6, 4, 1, 8, 0, 9, 2]
# 7058.0
# Processing file: t1s_0102.txt
# VectorInt[4, 1, 2, 0, 3]
# 4771.0
# Processing file: t1s_0167.txt
# VectorInt[7, 9, 4, 0, 8, 1, 2, 3, 6, 5]
# 4502.0
# Processing file: t1s_0318.txt
# VectorInt[2, 11, 5, 7, 8, 9, 10, 4, 0, 1, 3, 6]
# 9348.0
# Processing file: t1s_0007.txt
# VectorInt[3, 4, 2, 1, 0]
# 787.0
# Processing file: t1s_0005.txt
# VectorInt[0, 3, 2, 1, 4]
# 843.0
# Processing file: t1s_0241.txt
# VectorInt[3, 4, 9, 1, 10, 0, 11, 2, 6, 8, 7, 5]
# 3876.0
# Processing file: t1s_0315.txt
# VectorInt[3, 11, 0, 5, 7, 6, 4, 2, 10, 8, 9, 1]
# 9267.0
# Processing file: t1s_0139.txt
# VectorInt[2, 6, 4, 0, 7, 3, 1, 5, 9, 8]
# 3419.0
# Processing file: t1s_0047.txt
# VectorInt[3, 4, 1, 2, 0]
# 1868.0
# Processing file: t1s_0138.txt
# VectorInt[6, 3, 4, 8, 1, 2, 9, 0, 5, 7]
# 2222.0
# Processing file: t1s_0249.txt
# VectorInt[5, 2, 4, 10, 9, 0, 1, 6, 7, 8, 3, 11]
# 3638.0
# Processing file: t1s_0092.txt
# VectorInt[0, 3, 1, 2, 4]
# 4453.0
# Processing file: t1s_0235.txt
# VectorInt[2, 0, 9, 7, 3, 1, 4, 5, 8, 6]
# 12977.0
# Processing file: t1s_0359.txt
# VectorInt[7, 6, 11, 5, 4, 10, 1, 8, 9, 0, 2, 3]
# 15713.0
# Processing file: t1s_0020.txt
# VectorInt[4, 2, 0, 3, 1]
# 1153.0
# Processing file: t1s_0122.txt
# VectorInt[2, 0, 6, 7, 5, 3, 1, 8, 9, 4]
# 2751.0
# Processing file: t1s_0052.txt
# VectorInt[2, 1, 0, 3, 4]
# 1764.0
# Processing file: t1s_0154.txt
# VectorInt[6, 5, 4, 9, 0, 3, 2, 8, 7, 1]
# 4071.0
# Processing file: t1s_0142.txt
# VectorInt[4, 2, 0, 1, 3, 6, 5, 7, 9, 8]
# 3101.0
# Processing file: t1s_0207.txt
# VectorInt[4, 8, 3, 1, 2, 7, 6, 5, 0, 9]
# 6688.0
# Processing file: t1s_0182.txt
# VectorInt[5, 3, 2, 9, 6, 0, 8, 4, 7, 1]
# 7530.0
# Processing file: t1s_0037.txt
# VectorInt[3, 2, 4, 0, 1]
# 1467.0
# Processing file: t1s_0140.txt
# VectorInt[2, 4, 7, 0, 5, 8, 3, 9, 6, 1]
# 2233.0
# Processing file: t1s_0143.txt
# VectorInt[4, 9, 5, 3, 7, 1, 0, 2, 6, 8]
# 2463.0
# Processing file: t1s_0257.txt
# VectorInt[11, 5, 10, 8, 4, 3, 1, 0, 6, 7, 9, 2]
# 3043.0
# Processing file: t1s_0074.txt
# VectorInt[4, 2, 3, 1, 0]
# 2771.0
# Processing file: t1s_0290.txt
# VectorInt[2, 5, 6, 4, 0, 8, 3, 7, 11, 1, 9, 10]
# 6788.0
# Processing file: t1s_0358.txt
# VectorInt[7, 3, 9, 8, 2, 11, 6, 4, 1, 5, 0, 10]
# 15103.0
# Processing file: t1s_0177.txt
# VectorInt[0, 3, 5, 4, 9, 7, 2, 1, 6, 8]
# 4051.0
# Processing file: t1s_0080.txt
# VectorInt[0, 2, 4, 1, 3]
# 2453.0
# Processing file: t1s_0298.txt
# VectorInt[4, 8, 11, 1, 9, 6, 0, 10, 2, 5, 7, 3]
# 6447.0
# Processing file: t1s_0244.txt
# VectorInt[10, 11, 1, 3, 4, 2, 9, 0, 8, 7, 6, 5]
# 4286.0
# Processing file: t1s_0045.txt
# VectorInt[1, 0, 3, 2, 4]
# 1646.0
# Processing file: t1s_0123.txt
# VectorInt[6, 1, 3, 7, 9, 2, 5, 4, 0, 8]
# 3111.0
# Processing file: t1s_0276.txt
# VectorInt[11, 10, 0, 5, 6, 1, 3, 9, 2, 4, 8, 7]
# 6141.0
# Processing file: t1s_0064.txt
# VectorInt[3, 1, 4, 0, 2]
# 2425.0
# Processing file: t1s_0166.txt
# VectorInt[7, 6, 8, 2, 9, 3, 0, 4, 1, 5]
# 4975.0
# Processing file: t1s_0103.txt
# VectorInt[3, 0, 4, 2, 1]
# 5075.0
# Processing file: t1s_0194.txt
# VectorInt[6, 5, 2, 9, 3, 0, 1, 7, 4, 8]
# 6820.0
# Processing file: t1s_0050.txt
# VectorInt[0, 3, 4, 1, 2]
# 1532.0
# Processing file: t1s_0330.txt
# VectorInt[8, 4, 5, 0, 1, 9, 7, 10, 6, 2, 3, 11]
# 8742.0
# Processing file: t1s_0191.txt
# VectorInt[9, 4, 1, 7, 8, 2, 5, 6, 3, 0]
# 7161.0
# Processing file: t1s_0116.txt
# VectorInt[1, 2, 3, 0, 4]
# 4868.0
# Processing file: t1s_0095.txt
# VectorInt[1, 0, 3, 4, 2]
# 5151.0
# Processing file: t1s_0090.txt
# VectorInt[3, 4, 2, 1, 0]
# 3365.0
# Processing file: t1s_0243.txt
# VectorInt[7, 5, 9, 4, 1, 3, 8, 2, 0, 10, 11, 6]
# 4045.0
# Processing file: t1s_0259.txt
# VectorInt[1, 8, 10, 3, 0, 5, 4, 2, 11, 9, 6, 7]
# 2950.0
# Processing file: t1s_0201.txt
# VectorInt[6, 9, 4, 5, 0, 3, 8, 7, 2, 1]
# 6545.0
# Processing file: t1s_0321.txt
# VectorInt[6, 8, 0, 5, 9, 2, 11, 1, 3, 4, 10, 7]
# 10611.0
# Processing file: t1s_0008.txt
# VectorInt[4, 3, 1, 0, 2]
# 753.0
# Processing file: t1s_0285.txt
# VectorInt[4, 1, 11, 3, 0, 7, 10, 8, 9, 6, 2, 5]
# 7273.0
# Processing file: t1s_0220.txt
# VectorInt[2, 8, 6, 4, 7, 1, 3, 0, 5, 9]
# 11953.0
# Processing file: t1s_0175.txt
# VectorInt[1, 2, 7, 5, 8, 6, 9, 0, 4, 3]
# 3913.0
# Processing file: t1s_0195.txt
# VectorInt[7, 4, 3, 6, 2, 9, 1, 8, 0, 5]
# 6920.0
# Processing file: t1s_0083.txt
# VectorInt[1, 4, 2, 3, 0]
# 2391.0
# Processing file: t1s_0205.txt
# VectorInt[7, 1, 9, 5, 6, 0, 4, 2, 3, 8]
# 6686.0
# Processing file: t1s_0001.txt
# VectorInt[0, 1, 3, 2, 4]
# 819.0
# Processing file: t1s_0304.txt
# VectorInt[6, 8, 3, 7, 1, 10, 2, 0, 4, 11, 5, 9]
# 9471.0
# Processing file: t1s_0351.txt
# VectorInt[4, 10, 1, 6, 5, 3, 2, 9, 0, 8, 7, 11]
# 15632.0
# Processing file: t1s_0215.txt
# VectorInt[6, 7, 5, 2, 0, 1, 9, 4, 8, 3]
# 12761.0
# Processing file: t1s_0038.txt
# VectorInt[3, 4, 2, 1, 0]
# 1722.0
# Processing file: t1s_0055.txt
# VectorInt[1, 0, 2, 3, 4]
# 1156.0
# Processing file: t1s_0273.txt
# VectorInt[10, 11, 0, 4, 9, 1, 7, 6, 3, 5, 2, 8]
# 6312.0
# Processing file: t1s_0003.txt
# VectorInt[1, 4, 0, 3, 2]
# 791.0
# Processing file: t1s_0127.txt
# VectorInt[9, 3, 7, 6, 5, 8, 1, 4, 0, 2]
# 3173.0
# Processing file: t1s_0126.txt
# VectorInt[9, 2, 3, 4, 5, 0, 8, 7, 1, 6]
# 2758.0
# Processing file: t1s_0292.txt
# VectorInt[7, 2, 0, 8, 11, 9, 6, 3, 4, 10, 1, 5]
# 6136.0
# Processing file: t1s_0032.txt
# VectorInt[3, 4, 0, 2, 1]
# 1478.0
# Processing file: t1s_0262.txt
# VectorInt[11, 10, 0, 5, 1, 8, 9, 3, 7, 6, 2, 4]
# 3710.0
# Processing file: t1s_0058.txt
# VectorInt[0, 4, 1, 3, 2]
# 1867.0
# Processing file: t1s_0302.txt
# VectorInt[2, 1, 3, 7, 0, 9, 4, 11, 8, 6, 5, 10]
# 8606.0
# Processing file: t1s_0294.txt
# VectorInt[8, 0, 7, 1, 6, 2, 3, 4, 10, 9, 5, 11]
# 5993.0
# Processing file: t1s_0155.txt
# VectorInt[3, 5, 8, 6, 4, 7, 9, 2, 1, 0]
# 4916.0
# Processing file: t1s_0236.txt
# VectorInt[5, 0, 8, 7, 6, 4, 9, 1, 2, 3]
# 12864.0
# Processing file: t1s_0237.txt
# VectorInt[4, 1, 0, 5, 2, 9, 8, 7, 6, 3]
# 11816.0
# Processing file: t1s_0286.txt
# VectorInt[3, 7, 5, 4, 6, 8, 11, 10, 9, 2, 1, 0]
# 7136.0
# Processing file: t1s_0217.txt
# VectorInt[2, 8, 5, 1, 3, 7, 9, 6, 4, 0]
# 11143.0
# Processing file: t1s_0006.txt
# VectorInt[3, 4, 1, 0, 2]
# 735.0
# Processing file: t1s_0043.txt
# VectorInt[3, 4, 0, 1, 2]
# 1106.0
# Processing file: t1s_0026.txt
# VectorInt[4, 3, 1, 2, 0]
# 890.0
# Processing file: t1s_0181.txt
# VectorInt[4, 1, 7, 3, 2, 5, 0, 6, 9, 8]
# 6744.0
# Processing file: t1s_0044.txt
# VectorInt[3, 2, 1, 4, 0]
# 1697.0
# Processing file: t1s_0340.txt
# VectorInt[11, 4, 9, 10, 6, 5, 2, 0, 1, 8, 3, 7]
# 15696.0
# Processing file: t1s_0171.txt
# VectorInt[9, 2, 4, 8, 6, 1, 3, 0, 7, 5]
# 4448.0
# Processing file: t1s_0096.txt
# VectorInt[0, 3, 2, 4, 1]
# 4870.0
# Processing file: t1s_0075.txt
# VectorInt[3, 4, 2, 1, 0]
# 2491.0
# Processing file: t1s_0184.txt
# VectorInt[7, 8, 0, 5, 9, 6, 3, 4, 2, 1]
# 8643.0
# Processing file: t1s_0317.txt
# VectorInt[5, 6, 11, 7, 8, 3, 1, 2, 4, 9, 0, 10]
# 8908.0
# Processing file: t1s_0214.txt
# VectorInt[5, 8, 6, 3, 7, 2, 1, 0, 4, 9]
# 12566.0
# Processing file: t1s_0093.txt
# VectorInt[1, 2, 4, 3, 0]
# 4930.0
# Processing file: t1s_0219.txt
# VectorInt[3, 9, 6, 0, 1, 5, 7, 2, 4, 8]
# 11589.0
# Processing file: t1s_0310.txt
# VectorInt[0, 6, 3, 9, 5, 7, 4, 11, 2, 8, 1, 10]
# 9007.0
# Processing file: t1s_0086.txt
# VectorInt[1, 0, 3, 4, 2]
# 2869.0
# Processing file: t1s_0332.txt
# VectorInt[9, 8, 6, 11, 5, 3, 10, 7, 2, 0, 4, 1]
# 15811.0
# Processing file: t1s_0320.txt
# VectorInt[5, 4, 1, 6, 0, 9, 3, 2, 8, 10, 11, 7]
# 10005.0
# Processing file: t1s_0010.txt
# VectorInt[0, 4, 1, 3, 2]
# 885.0
# Processing file: t1s_0354.txt
# VectorInt[10, 2, 1, 5, 8, 7, 9, 0, 3, 6, 11, 4]
# 16699.0
# Processing file: t1s_0112.txt
# VectorInt[2, 4, 1, 0, 3]
# 4754.0
# Processing file: t1s_0245.txt
# VectorInt[3, 11, 10, 5, 1, 7, 4, 0, 2, 8, 6, 9]
# 4427.0
# Processing file: t1s_0173.txt
# VectorInt[4, 2, 9, 1, 8, 6, 7, 3, 5, 0]
# 5160.0
# Processing file: t1s_0030.txt
# VectorInt[4, 3, 1, 2, 0]
# 815.0
# Processing file: t1s_0189.txt
# VectorInt[8, 3, 9, 0, 7, 6, 1, 4, 2, 5]
# 7820.0
# Processing file: t1s_0054.txt
# VectorInt[1, 2, 0, 4, 3]
# 1337.0
# Processing file: t1s_0120.txt
# VectorInt[4, 1, 2, 0, 3]
# 4478.0
# Processing file: t1s_0289.txt
# VectorInt[2, 0, 5, 6, 10, 4, 11, 3, 8, 7, 1, 9]
# 5062.0
# Processing file: t1s_0087.txt
# VectorInt[2, 1, 4, 3, 0]
# 2499.0
# Processing file: t1s_0101.txt
# VectorInt[0, 3, 2, 1, 4]
# 4048.0
# Processing file: t1s_0176.txt
# VectorInt[6, 9, 2, 5, 0, 3, 8, 1, 7, 4]
# 4037.0
# Processing file: t1s_0073.txt
# VectorInt[2, 0, 4, 1, 3]
# 2691.0
# Processing file: t1s_0002.txt
# VectorInt[2, 1, 3, 0, 4]
# 786.0
# Processing file: t1s_0085.txt
# VectorInt[0, 4, 1, 3, 2]
# 2215.0
# Processing file: t1s_0353.txt
# VectorInt[10, 5, 7, 8, 9, 11, 0, 1, 3, 6, 4, 2]
# 14873.0
# Processing file: t1s_0159.txt
# VectorInt[4, 8, 6, 0, 1, 5, 9, 7, 3, 2]
# 4691.0
# Processing file: t1s_0198.txt
# VectorInt[2, 0, 1, 4, 7, 5, 3, 8, 6, 9]
# 7330.0
# Processing file: t1s_0104.txt
# VectorInt[1, 4, 0, 3, 2]
# 4721.0
# Processing file: t1s_0089.txt
# VectorInt[1, 0, 2, 4, 3]
# 2725.0
# Processing file: t1s_0016.txt
# VectorInt[4, 3, 0, 2, 1]
# 841.0
# Processing file: t1s_0136.txt
# VectorInt[4, 9, 3, 1, 2, 6, 8, 7, 0, 5]
# 2621.0
# Processing file: t1s_0337.txt
# VectorInt[9, 1, 4, 6, 8, 10, 5, 0, 11, 3, 7, 2]
# 15416.0
# Processing file: t1s_0109.txt
# VectorInt[0, 2, 3, 1, 4]
# 5101.0
# Processing file: t1s_0012.txt
# VectorInt[3, 0, 1, 4, 2]
# 961.0
# Processing file: t1s_0334.txt
# VectorInt[6, 11, 3, 8, 1, 7, 5, 2, 0, 10, 4, 9]
# 15213.0
# Processing file: t1s_0156.txt
# VectorInt[6, 7, 4, 5, 1, 0, 2, 9, 3, 8]
# 4014.0
# Processing file: t1s_0023.txt
# VectorInt[4, 0, 2, 1, 3]
# 680.0
# Processing file: t1s_0011.txt
# VectorInt[1, 4, 2, 0, 3]
# 1064.0
# Processing file: t1s_0097.txt
# VectorInt[2, 4, 0, 1, 3]
# 4673.0
# Processing file: t1s_0135.txt
# VectorInt[2, 8, 4, 6, 5, 0, 1, 7, 3, 9]
# 2956.0
# Processing file: t1s_0308.txt
# VectorInt[10, 2, 5, 1, 9, 11, 8, 6, 4, 0, 7, 3]
# 10023.0
# Processing file: t1s_0307.txt
# VectorInt[8, 3, 0, 5, 9, 4, 6, 11, 10, 7, 1, 2]
# 8490.0
# Processing file: t1s_0069.txt
# VectorInt[4, 2, 1, 0, 3]
# 2803.0
# Processing file: t1s_0066.txt
# VectorInt[0, 1, 4, 2, 3]
# 2602.0
# Processing file: t1s_0150.txt
# VectorInt[5, 7, 0, 6, 4, 1, 8, 3, 9, 2]
# 2607.0
# Processing file: t1s_0283.txt
# VectorInt[10, 0, 6, 11, 8, 4, 3, 7, 1, 5, 9, 2]
# 6298.0
# Processing file: t1s_0017.txt
# VectorInt[3, 4, 1, 0, 2]
# 740.0
# Processing file: t1s_0258.txt
# VectorInt[7, 3, 9, 2, 6, 1, 11, 0, 5, 10, 4, 8]
# 3781.0
# Processing file: t1s_0036.txt
# VectorInt[2, 1, 3, 0, 4]
# 1523.0
# Processing file: t1s_0053.txt
# VectorInt[4, 2, 1, 0, 3]
# 1403.0
# Processing file: t1s_0163.txt
# VectorInt[4, 1, 7, 3, 2, 6, 8, 5, 9, 0]
# 4258.0
# Processing file: t1s_0067.txt
# VectorInt[1, 2, 4, 0, 3]
# 3002.0
# Processing file: t1s_0341.txt
# VectorInt[7, 1, 10, 6, 3, 2, 9, 5, 11, 8, 0, 4]
# 14450.0
# Processing file: t1s_0084.txt
# VectorInt[0, 4, 3, 1, 2]
# 2271.0
# Processing file: t1s_0033.txt
# VectorInt[3, 1, 2, 0, 4]
# 1634.0
# Processing file: t1s_0293.txt
# VectorInt[3, 11, 9, 8, 1, 0, 5, 4, 7, 6, 10, 2]
# 5434.0
# Processing file: t1s_0339.txt
# VectorInt[7, 9, 0, 10, 2, 6, 11, 8, 5, 4, 3, 1]
# 15091.0
# Processing file: t1s_0228.txt
# VectorInt[9, 6, 7, 5, 0, 8, 4, 1, 2, 3]
# 11703.0
# Processing file: t1s_0132.txt
# VectorInt[6, 2, 7, 1, 4, 3, 8, 0, 5, 9]
# 3249.0
# Processing file: t1s_0233.txt
# VectorInt[8, 3, 0, 5, 2, 7, 1, 6, 4, 9]
# 11415.0
# Processing file: t1s_0078.txt
# VectorInt[4, 1, 3, 2, 0]
# 2323.0
# Processing file: t1s_0348.txt
# VectorInt[8, 5, 2, 11, 0, 4, 3, 10, 6, 9, 7, 1]
# 16150.0
# Processing file: t1s_0061.txt
# VectorInt[1, 2, 0, 4, 3]
# 2562.0
# Processing file: t1s_0323.txt
# VectorInt[0, 9, 11, 2, 6, 8, 4, 10, 5, 3, 1, 7]
# 9221.0
# Processing file: t1s_0270.txt
# VectorInt[10, 5, 6, 1, 11, 7, 9, 4, 0, 8, 3, 2]
# 3681.0
# Processing file: t1s_0121.txt
# VectorInt[6, 2, 7, 0, 8, 5, 4, 9, 3, 1]
# 2948.0
# Processing file: t1s_0224.txt
# VectorInt[7, 6, 0, 3, 4, 5, 1, 2, 8, 9]
# 12580.0
# Processing file: t1s_0019.txt
# VectorInt[4, 1, 3, 2, 0]
# 1412.0
# Processing file: t1s_0172.txt
# VectorInt[7, 6, 8, 5, 9, 4, 0, 2, 3, 1]
# 3344.0
# Processing file: t1s_0347.txt
# VectorInt[4, 9, 10, 1, 2, 5, 0, 8, 7, 11, 3, 6]
# 15062.0
# Processing file: t1s_0197.txt
# VectorInt[5, 6, 2, 9, 0, 1, 4, 3, 7, 8]
# 7183.0
# Processing file: t1s_0272.txt
# VectorInt[3, 2, 1, 7, 5, 4, 0, 11, 9, 8, 10, 6]
# 5120.0
# Processing file: t1s_0134.txt
# VectorInt[9, 1, 2, 7, 0, 8, 3, 6, 4, 5]
# 2224.0
# Processing file: t1s_0250.txt
# VectorInt[9, 10, 0, 11, 2, 7, 8, 6, 4, 3, 1, 5]
# 3049.0
# Processing file: t1s_0204.txt
# VectorInt[9, 4, 5, 0, 6, 8, 7, 1, 2, 3]
# 7775.0
# Processing file: t1s_0267.txt
# VectorInt[11, 10, 4, 5, 8, 7, 0, 6, 3, 9, 2, 1]
# 3655.0
# Processing file: t1s_0254.txt
# VectorInt[9, 4, 10, 7, 2, 11, 6, 8, 5, 1, 0, 3]
# 4097.0
# Processing file: t1s_0278.txt
# VectorInt[6, 0, 1, 10, 9, 11, 3, 4, 7, 8, 2, 5]
# 6504.0
# Processing file: t1s_0325.txt
# VectorInt[10, 1, 11, 0, 6, 7, 4, 8, 5, 9, 2, 3]
# 8943.0
# Processing file: t1s_0319.txt
# VectorInt[6, 0, 11, 5, 4, 2, 3, 1, 9, 7, 10, 8]
# 8936.0
# Processing file: t1s_0279.txt
# VectorInt[10, 6, 4, 7, 9, 0, 5, 11, 1, 2, 8, 3]
# 5751.0
# Processing file: t1s_0202.txt
# VectorInt[8, 9, 6, 0, 7, 4, 2, 5, 3, 1]
# 6719.0
# Processing file: t1s_0356.txt
# VectorInt[10, 1, 8, 9, 0, 11, 7, 6, 3, 4, 2, 5]
# 15449.0
# Processing file: t1s_0041.txt
# VectorInt[4, 2, 1, 0, 3]
# 1601.0
# Processing file: t1s_0188.txt
# VectorInt[0, 9, 8, 3, 7, 4, 1, 6, 2, 5]
# 7688.0
# Processing file: t1s_0199.txt
# VectorInt[4, 0, 1, 2, 3, 9, 6, 7, 5, 8]
# 7400.0
# Processing file: t1s_0242.txt
# VectorInt[3, 5, 1, 7, 6, 11, 9, 10, 4, 8, 0, 2]
# 3029.0
# Processing file: t1s_0170.txt
# VectorInt[6, 1, 8, 2, 3, 7, 9, 0, 5, 4]
# 4640.0
# Processing file: t1s_0360.txt
# VectorInt[5, 11, 0, 7, 3, 6, 8, 4, 10, 2, 1, 9]
# 16970.0
# Processing file: t1s_0247.txt
# VectorInt[0, 3, 2, 4, 11, 7, 5, 10, 1, 8, 9, 6]
# 3716.0
# Processing file: t1s_0004.txt
# VectorInt[4, 3, 0, 2, 1]
# 828.0

# %%
results.sort(key=lambda x: x["filename"])
write_results_to_csv(results, output_file)
